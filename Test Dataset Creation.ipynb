# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import random
import shutil
data_dir = '/kaggle/input/comp6321-project-datasets/'
test_dir = '/kaggle/Test100/'
counter=0
for root, dirs, files in os.walk(data_dir):
    if len(files)>0:
        end_length = len(files)
        if counter>=76:
            random_indices = [random.randint(0, end_length) for _ in range(12)]
        else:
            random_indices = [random.randint(0, end_length) for _ in range(11)]
        ctr = 0
        files = [files[i] for i in random_indices]
        for file in files:
            print(root)
            print(file)
            print('--------------------')
            filepath = root+'/'+file
            print(str(counter)+':'+ filepath)
            new_path = root[len(data_dir):]
            print(str(counter)+':'+test_dir+new_path)
            print("---------------------------------")
            counter+=1
            ctr +=1
            if not os.path.exists(test_dir+new_path):
                print('making the needed directory')
                os.makedirs(test_dir+new_path)
            shutil.copy2(filepath, test_dir+new_path)
# Out:
# /kaggle/input/comp6321-project-datasets/Dataset 2/Dataset 2/Prostate Cancer/tumor
# tu.236.jpg
# --------------------
# 0:/kaggle/input/comp6321-project-datasets/Dataset 2/Dataset 2/Prostate Cancer/tumor/tu.236.jpg
# 0:/kaggle/Test100/Dataset 2/Dataset 2/Prostate Cancer/tumor
# ---------------------------------
# making the needed directory
# /kaggle/input/comp6321-project-datasets/Dataset 2/Dataset 2/Prostate Cancer/tumor
# tu.1860.jpg
# --------------------
# 1:/kaggle/input/comp6321-project-datasets/Dataset 2/Dataset 2/Prostate Cancer/tumor/tu.1860.jpg
# 1:/kaggle/Test100/Dataset 2/Dataset 2/Prostate Cancer/tumor
# ---------------------------------
# /kaggle/input/comp6321-project-datasets/Dataset 2/Dataset 2/Prostate Cancer/tumor
# tu.305.jpg
# --------------------
# 2:/kaggle/input/comp6321-project-datasets/Dataset 2/Dataset 2/Prostate Cancer/tumor/tu.305.jpg
# 2:/kaggle/Test100/Dataset 2/Dataset 2/Prostate Cancer/tumor
# ---------------------------------
# ...

# %%
import zipfile
import os
from IPython.display import FileLink

def zip_dir(directory = os.curdir, file_name = 'directory.zip'):
    """
    zip all the files in a directory
    
    Parameters
    _____
    directory: str
        directory needs to be zipped, defualt is current working directory
        
    file_name: str
        the name of the zipped file (including .zip), default is 'directory.zip'
        
    Returns
    _____
    Creates a hyperlink, which can be used to download the zip file)
    """
    #os.chdir(directory)
    zip_ref = zipfile.ZipFile(file_name, mode='w')
    for folder, _, files in os.walk(directory):
        for file in files:
            if file_name in file:
                pass
            else:
                zip_ref.write(os.path.join(folder, file))

    return FileLink(file_name)

# %%
zip_dir(directory ='/kaggle/Test100/' , file_name ='Test100.zip')
# Out:
# /kaggle/working/Test100.zip
